# %% [markdown]
# # Start pandas library

# %%
import pandas as pd

# %%
print("Hello world")
# Out:
# Hello world

# %%
# series in pandas (string)
country = 'India','Japan','Mexico','Brazil'
pd.Series(country)
# Out:
# 0     India
# 1     Japan
# 2    Mexico
# 3    Brazil
# dtype: object

# %%
# Integer
runs = [25,24,53,55,98]
pd.Series(runs)
# Out:
# 0    25
# 1    24
# 2    53
# 3    55
# 4    98
# dtype: int64

# %%
# Custom index
students = ['Navjot','Kiran','Sukhvindar','Mohan']
marks = [40,50,60,80]
pd.Series(students,index=marks)
# Out:
# 40        Navjot
# 50         Kiran
# 60    Sukhvindar
# 80         Mohan
# dtype: object

# %%
# specific name acc.to.you
marks = pd.Series(students,index=marks,name = 'kusina marks')

# %%
# series unsing dict
students_or_marks = {'Navjot':54,
                     'Kiran':76,
                     'Sukhvindar':80,
                     'Mohan':99}
marks_st = pd.Series(students_or_marks,name = 'class student result')
marks_st
# Out:
# Navjot        54
# Kiran         76
# Sukhvindar    80
# Mohan         99
# Name: class student result, dtype: int64

# %% [markdown]
# # Series attributtes

# %%
# size 
marks_st.size
# Out:
# 4

# %%
# data type
marks_st.dtype
# Out:
# dtype('int64')

# %%
# name of series
marks_st.name
# Out:
# 'class student result'

# %%
# is unique
marks_st.is_unique
# Out:
# True

# %%
# index 
marks_st.index
# Out:
# Index(['Navjot', 'Kiran', 'Sukhvindar', 'Mohan'], dtype='object')

# %%
# values 
marks_st.values
# Out:
# array([54, 76, 80, 99])

# %%
# With 1 cols
import pandas as pd 
subs = pd.read_csv('subs.csv').squeeze()
type(subs)
# Out:
# pandas.core.series.Series

# %%
# With 2 cols
kohli = pd.read_csv('kohli_ipl.csv', index_col='match_no').squeeze("columns").copy()
kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie = pd.read_csv('bollywood.csv',index_col='movie').squeeze("columns")
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# head and tail on these real world problem
movie.head() # By default is five 
subs.head(10)
# tail
kohli.tail() # By defalult they are also five
kohli.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# Sample (it gives random value)
movie.sample()
movie.sample(5) # you also give the number how many random files you want
# Out:
# movie
# Aashayein                        John Abraham
# Mai (2013 film)                   Asha Bhosle
# Revolver Rani                  Kangana Ranaut
# Right Here Right Now (film)             Ankit
# Ek Kahani Julie Ki               Jimmy Sharma
# Name: lead, dtype: object

# %%
# Value_counts (it provide how many movie or how many score you get it by one actor or gamer  )
movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values ----IF YOU WANT GREATEST OR SORTEST SCORE OR NUMBER
kohli.sort_values(ascending=False).head(1).values[0]
# when you doing this your orignal Value does not change but when you apply this below trick and you want your orignal data change with this one data so here is the trick 
kohli.sort_values(invoice=True)

# %%
# Sort_index --- Here movies or your any type of data arrange alphabetically
movie.sort_index()# Here you also use this (invoice=True) to save your data acc.to.you
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Series Maths Methods

# %%
# counts 
kohli.count()
# Out:
# np.int64(215)

# %%
#sum ---> product
kohli.sum()
kohli.product()
# Out:
# np.int64(0)

# %%
# Mean---> Median---->Mode------>standard---->Variation
subs.mean()
kohli.median()
movie.mode()
subs.std()
subs.var()
# Out:
# 3928.1585127201556

# %%
# Min /  Max
subs.min()
subs.max()
# Out:
# 396

# %%
# describe
kohli.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# # Series Indexing

# %%
# Integer indexing 
x = pd.Series([34,44,64,65,24,65,87,97,94])
x[1]
# Out:
# np.int64(44)

# %%
# Negative inndexing 
x.values[-1]
# Out:
# np.int64(94)

# %%
# Slicing 
kohli[5:17]
# Out:
# match_no
# 93     0
# 8      0
# 130    0
# 135    0
# 106    1
# 113    1
# 77     1
# 75     1
# 1      1
# 174    1
# 5      1
# 204    1
# Name: runs, dtype: int64

# %%
# Negative slicing -----> Gaph slicing 
subs[-5:] 
movie[::3]
# Out:
# movie
# Uri: The Surgical Strike             Vicky Kaushal
# Why Cheat India                      Emraan Hashmi
# Fraud Saiyaan                         Arshad Warsi
# Thackeray (film)               Nawazuddin Siddiqui
# Hum Chaar                              Prit Kamani
#                                       ...
# Talaash: The Hunt Begins...          Rakhee Gulzar
# Yeh Dil                             Tusshar Kapoor
# Zameen (2003 film)                      Ajay Devgn
# Kaante                            Amitabh Bachchan
# Saathiya (film)                       Vivek Oberoi
# Name: lead, Length: 500, dtype: object

# %%
# Fancy indexing 
movie[[1,4,5,7]]
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_16404\956149787.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movie[[1,4,5,7]]
# movie
# Battalion 609               Vicky Ahuja
# Evening Shadows        Mona Ambegaonkar
# Soni (film)        Geetika Vidya Ohlyan
# Bombairiya                 Radhika Apte
# Name: lead, dtype: object

# %%
# label indexing
movie['Hum Tumhare Hain Sanam']
# Out:
# 'Shah Rukh Khan'

# %% [markdown]
# # Editing Series

# %%
# using indexing you change your data acc.to.you
marks_st[1] = 100
marks_st
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_16404\1544871606.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_st[1] = 100
# Navjot         54
# Kiran         100
# Sukhvindar     80
# Mohan          99
# Name: class student result, dtype: int64

# %%
# what if an index is not exsist
marks_st['sst'] = 94
marks_st
# Out:
# Navjot         54
# Kiran         100
# Sukhvindar     80
# Mohan          99
# sst            94
# Name: class student result, dtype: int64

# %%
# You also change the values through the slicing 
marks_st[2:4] = [65,90]
marks_st
# Out:
# Navjot         54
# Kiran         100
# Sukhvindar     65
# Mohan          90
# sst            94
# Name: class student result, dtype: int64

# %%
# Using fancy indexing
marks_st[[1,2,3]] = [90,90,90]
marks_st
# Out:
# C:\Users\ratho\AppData\Local\Temp\ipykernel_16404\2924245586.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_st[[1,2,3]] = [90,90,90]
# Navjot        54
# Kiran         90
# Sukhvindar    90
# Mohan         90
# sst           94
# Name: class student result, dtype: int64

# %%
# Label indexing 
movie['Battalion 609'] = 'kirti sanon'
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                kirti sanon
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Series with python functaonality

# %%
# len--type--dir---max---min-----sorted
print(len(subs))
print(type(subs))
print(dir(subs))
print(max(subs))
print(min(subs))
print(sorted(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(marks_st)
dict(marks_st)
# Out:
# {'Navjot': np.int64(54),
#  'Kiran': np.int64(90),
#  'Sukhvindar': np.int64(90),
#  'Mohan': np.int64(90),
#  'sst': np.int64(94)}

# %%
# Membership opreator only works in index not values if you want that will work on value you right this .values
'The Accidental Prime Minister (film)' in movie
'Mona Ambegaonkar' in movie.values
# Out:
# True

# %%
# Looping only works in values not if you want that  will work on index you right this .index
for i in movie:
    print(i)
for i in movie.index:
    print(i)
# Out:
# Vicky Kaushal
# kirti sanon
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
# Airthmetic opreator (Here you use all opreator acc-to-you)
100 - marks_st
# Out:
# Navjot        46
# Kiran         10
# Sukhvindar    10
# Mohan         10
# sst            6
# Name: class student result, dtype: int64

# %%
# Relaqtional opreator (condtion use)
kohli >= 50
# Out:
# match_no
# 87     False
# 211    False
# 207    False
# 206    False
# 91     False
#        ...
# 164     True
# 120     True
# 123     True
# 126     True
# 128     True
# Name: runs, Length: 215, dtype: bool

# %%
# Boolean indexing on series 
kohli[kohli >= 100].size
# Out:
# 6

# %%
# Find number of Ducks (ducks means 0
kohli[kohli == 0]
# Out:
# match_no
# 87     0
# 211    0
# 207    0
# 206    0
# 91     0
# 93     0
# 8      0
# 130    0
# 135    0
# Name: runs, dtype: int64

# %%
# Find the actors name who have dono 20 movies 
movie_s = movie.value_counts()
movie_s[movie_s > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ## Plotting graph on series

# %%
subs.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
movie.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movie.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
